# %%
from sklearn import tree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %%
from IPython.display import SVG
# from graphviz import Source
# from python-graphviz import Source
from IPython.display import display

from IPython.display import HTML
style = "<style>svg{width:10% !important;height:10% !important;}</style>"
HTML(style)
# Out:
# <style>svg{width:10% !important;height:10% !important;}</style>

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/training_mush.csv')

# %%
df.head()
# Out:
#    cap-shape  cap-surface  cap-color  ...  population  habitat  class
# 0          2            0          3  ...           5        0      0
# 1          2            0          4  ...           4        0      1
# 2          2            0          3  ...           5        1      1
# 3          0            0          3  ...           3        1      0
# 4          2            3          3  ...           5        0      0
#
# [5 rows x 23 columns]

# %%
# разбиваем выборку
X_train = df.drop(['class'], axis = 1)
y_train = df['class']

# %%
# задаем объект с параметрами, которые нужно перебрать
parameters = {
    'n_estimators': range(10, 51, 10), 
    'max_depth': range(1, 13, 2),
    'min_samples_leaf': range(1, 8),
    'min_samples_split': range(2, 10, 2),
}

# %%
# Подбираем оптимальные параметры
# n_jobs=-1 чтобы использовать все процессоры
clf_rf = RandomForestClassifier(random_state=0)
grid_search_cv_clf_rf = GridSearchCV(clf_rf, parameters, cv = 3, n_jobs=-1)

# %%
grid_search_cv_clf_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=0,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'max_depth': range(1, 13, 2),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10, 2),
#                          'n_estimators': range(10, 51, 10)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
grid_search_cv_clf_rf.best_params_
# Out:
# {'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
best_tree_rg = grid_search_cv_clf_rf.best_estimator_

# %%
x_test = pd.read_csv('https://stepik.org/media/attachments/course/4852/testing_mush.csv')

# %%
x_test.head()
# Out:
#    cap-shape  cap-surface  cap-color  ...  spore-print-color  population  habitat
# 0          0            3          8  ...                  2           3        3
# 1          5            3          4  ...                  3           5        0
# 2          3            3          4  ...                  7           4        4
# 3          3            2          2  ...                  7           4        0
# 4          3            2          2  ...                  7           4        4
#
# [5 rows x 22 columns]

# %%
# посчитаем количество положительныз ответов на предсказанной модели
y_pred = grid_search_cv_clf_rf.predict(X_train)
sum(grid_search_cv_clf_rf.predict(x_test))
# Out:
# 976

# %%
# построим матрицу предсказанных и тренировочных значений

from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_train, y_pred)
# Out:
# array([[3153,    0],
#        [   0, 2940]])

# %%
df_fate = pd.read_csv('https://stepik.org/media/attachments/course/4852/invasion.csv')

# %%
df_fate.head(20)
# Out:
#         class  g_reflection  ...  time_of_observance      volume
# 0   transport      2.190672  ...              158221   44.932446
# 1   transport      3.453276  ...              385972   41.568300
# 2   transport      2.432994  ...              446482   40.123467
# 3     fighter      6.083763  ...              210125   11.384865
# 4     fighter     12.876769  ...               23109   11.328806
# 5     cruiser     11.839620  ...              366230  344.868989
# 6   transport      3.583082  ...              268752   48.811194
# 7     fighter     16.185380  ...              130305   11.063792
# 8   transport      3.428605  ...              358659   46.378304
# 9   transport      3.632056  ...              493153   43.070987
# 10    fighter      9.468371  ...               28856   13.880644
# 11    fighter     12.146224  ...              380638   10.142749
# 12    fighter     13.283433  ...              552164   11.802099
# 13    fighter      9.260027  ...               21320   11.062829
# 14  transport      3.232512  ...              227919   45.665558
# 15    cruiser     12.250561  ...              159260  452.830016
# 16  transport      5.622813  ...              177124   39.752419
# 17  transport      2.860564  ...              101845   42.164301
# 18  transport      2.617450  ...              369363   49.388060
# 19    fighter      8.260850  ...              193192   13.704267
#
# [20 rows x 7 columns]

# %%
# разбиваем выборку
X_train = df_fate.drop(['class'], axis = 1)
y_train = df_fate['class']

# %%
# задаем объект с параметрами, которые нужно перебрать
parameters = {
    'n_estimators': range(10, 51, 10), 
    'max_depth': range(1, 13, 2),
    'min_samples_leaf': range(1, 8),
    'min_samples_split': range(2, 10, 2),
}

# Подбираем оптимальные параметры
# n_jobs=-1 чтобы использовать все процессоры
clf_rf = RandomForestClassifier(random_state=0)
grid_search_cv_clf_rf = GridSearchCV(clf_rf, parameters, cv = 3, n_jobs=-1)

grid_search_cv_clf_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=0,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'max_depth': range(1, 13, 2),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10, 2),
#                          'n_estimators': range(10, 51, 10)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
X_test = pd.read_csv('https://stepik.org/media/attachments/course/4852/operative_information.csv')
pred = grid_search_cv_clf_rf.predict(X_test)

# %%
# посчитаем кол-во элементов в предсказанной моделиЫ
unique, counts = np.unique(pred, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'cruiser': 230, 'fighter': 675, 'transport': 595}

# %%
# Out:
# (array(['cruiser', 'fighter', 'transport'], dtype=object),
#  array([230, 675, 595]))
